# %%
from pymongo import MongoClient

# %%
Student = MongoClient('mongodb://Username:password@ac-3bej3sm-shard-00-00.ihjs01k.mongodb.net:27017,ac-3bej3sm-shard-00-01.ihjs01k.mongodb.net:27017,ac-3bej3sm-shard-00-02.ihjs01k.mongodb.net:27017/?ssl=true&replicaSet=atlas-z1iftn-shard-0&authSource=admin&retryWrites=true&w=majority')

# %%
db = Student['studentDB']
Collection = db['dataset']

# %%
import pandas as pd

df = pd.read_json("students.json", lines = True)
df
# Out:
#      _id              name                                             scores
# 0      0        aimee Zank  [{'score': 1.463179736705023, 'type': 'exam'},...
# 1      1  Aurelia Menendez  [{'score': 60.06045071030959, 'type': 'exam'},...
# 2      2       Corliss Zuk  [{'score': 67.03077096065002, 'type': 'exam'},...
# 3      3        Bao Ziglar  [{'score': 71.64343899778332, 'type': 'exam'},...
# 4      4  Zachary Langlais  [{'score': 78.68385091304332, 'type': 'exam'},...
# ..   ...               ...                                                ...
# 195  195     Linnie Weigel  [{'score': 52.44578368517977, 'type': 'exam'},...
# 196  196  Santiago Dollins  [{'score': 52.04052571137036, 'type': 'exam'},...
# 197  197     Tonisha Games  [{'score': 38.51269589995049, 'type': 'exam'},...
# 198  198    Timothy Harrod  [{'score': 11.9075674046519, 'type': 'exam'}, ...
# 199  199        Rae Kohout  [{'score': 82.11742562118049, 'type': 'exam'},...
#
# [200 rows x 3 columns]

# %%
print(df['scores'][0][0])
print(df['scores'][0][1])
print(df['scores'][0][2])
# Out:
# {'score': 1.463179736705023, 'type': 'exam'}
# {'score': 11.78273309957772, 'type': 'quiz'}
# {'score': 35.8740349954354, 'type': 'homework'}

# %%
print(len(df['scores']))
# Out:
# 200

# %%
exam = []
quiz = []
homework = []

for i in range(len(df['scores'])):
    exam.append(df['scores'][i][0]['score'])
    quiz.append(df['scores'][i][1]['score'])
    homework.append(df['scores'][i][2]['score'])
# print(exam)
# print(quiz)
# print(homework)

# %%
df['Exam'] = exam
df['Quiz'] =quiz
df['Homework'] = homework
df
# Out:
#      _id              name                                             scores  \
# 0      0        aimee Zank  [{'score': 1.463179736705023, 'type': 'exam'},...
# 1      1  Aurelia Menendez  [{'score': 60.06045071030959, 'type': 'exam'},...
# 2      2       Corliss Zuk  [{'score': 67.03077096065002, 'type': 'exam'},...
# 3      3        Bao Ziglar  [{'score': 71.64343899778332, 'type': 'exam'},...
# 4      4  Zachary Langlais  [{'score': 78.68385091304332, 'type': 'exam'},...
# ..   ...               ...                                                ...
# 195  195     Linnie Weigel  [{'score': 52.44578368517977, 'type': 'exam'},...
# 196  196  Santiago Dollins  [{'score': 52.04052571137036, 'type': 'exam'},...
# 197  197     Tonisha Games  [{'score': 38.51269589995049, 'type': 'exam'},...
# 198  198    Timothy Harrod  [{'score': 11.9075674046519, 'type': 'exam'}, ...
# 199  199        Rae Kohout  [{'score': 82.11742562118049, 'type': 'exam'},...
#
# ...

# %%
for i in range(len(df)):
    x=df.iloc[i].to_dict()
    Collection.insert_one(x)

# %%
df.drop(['scores'],axis=1,inplace=True)
df.drop(['_id'],axis=1,inplace=True)

# %%
df
# Out:
#                  name       Exam       Quiz   Homework
# 0          aimee Zank   1.463180  11.782733  35.874035
# 1    Aurelia Menendez  60.060451  52.797907  71.761334
# 2         Corliss Zuk  67.030771   6.301852  66.283447
# 3          Bao Ziglar  71.643439  24.802213  42.261471
# 4    Zachary Langlais  78.683851  90.296310  34.416201
# ..                ...        ...        ...        ...
# 195     Linnie Weigel  52.445784  90.777505  11.750084
# 196  Santiago Dollins  52.040526  33.633001  78.792574
# 197     Tonisha Games  38.512696  31.162876  79.158564
# 198    Timothy Harrod  11.907567  20.518800  64.856504
# 199        Rae Kohout  82.117426  49.612955  28.868237
#
# [200 rows x 4 columns]

# %%
df['Total'] =df.loc[:,['Exam','Quiz','Homework']].sum(axis=1)
df['Percentage'] = df.loc[:,['Exam','Quiz','Homework']].mean(axis=1)
df
# Out:
#                  name       Exam       Quiz   Homework       Total  Percentage
# 0          aimee Zank   1.463180  11.782733  35.874035   49.119948   16.373316
# 1    Aurelia Menendez  60.060451  52.797907  71.761334  184.619692   61.539897
# 2         Corliss Zuk  67.030771   6.301852  66.283447  139.616069   46.538690
# 3          Bao Ziglar  71.643439  24.802213  42.261471  138.707123   46.235708
# 4    Zachary Langlais  78.683851  90.296310  34.416201  203.396363   67.798788
# ..                ...        ...        ...        ...         ...         ...
# 195     Linnie Weigel  52.445784  90.777505  11.750084  154.973373   51.657791
# 196  Santiago Dollins  52.040526  33.633001  78.792574  164.466100   54.822033
# 197     Tonisha Games  38.512696  31.162876  79.158564  148.834135   49.611378
# 198    Timothy Harrod  11.907567  20.518800  64.856504   97.282871   32.427624
# 199        Rae Kohout  82.117426  49.612955  28.868237  160.598617   53.532872
#
# [200 rows x 6 columns]

# %%
for i in range(len(df)):
    x=df.iloc[i].to_dict()
    Collection.insert_one(x)

# %% [raw]
# # Find the student name who scored maximum scores in all (exam, quiz and homework)

# %%
for i in Collection.find().sort('Total',-1).limit(1):
    print(i['name'])
# Out:
# Jessika Dagenais

# %% [raw]
# # Find students who scored below average in the exam and pass mark is 40%

# %%
for i in Collection.find({'Exam':{'$lte':40}}).sort('Exam', -1):
    print(i['name'])
# Out:
# Fletcher Mcconnell
# Fletcher Mcconnell
# Len Treiber
# Len Treiber
# Kurtis Jiles
# Kurtis Jiles
# Tonisha Games
# Tonisha Games
# Ty Barbieri
# Ty Barbieri
# Jenette Flanders
# Jenette Flanders
# Bao Ziglar
# Bao Ziglar
# Rubie Winton
# Rubie Winton
# Gwen Honig
# Gwen Honig
# Joaquina Arbuckle
# Joaquina Arbuckle
# Barbera Lippman
# Barbera Lippman
# Richelle Siemers
# Richelle Siemers
# Harriett Velarde
# Harriett Velarde
# Santiago Dollins
# Santiago Dollins
# Malisa Jeanes
# Malisa Jeanes
# Rudolph Domingo
# Rudolph Domingo
# Cody Strouth
# Cody Strouth
# Leola Lundin
# Leola Lundin
# Ta Sikorski
# Ta Sikorski
# Kim Xu
# Kim Xu
# Tonisha Games
# Tonisha Games
# Joaquina Arbuckle
# Joaquina Arbuckle
# Aleida Elsass
# Aleida Elsass
# Echo Pippins
# Echo Pippins
# Lucinda Vanderburg
# Lucinda Vanderburg
# Synthia Labelle
# Synthia Labelle
# Alix Sherrill
# Alix Sherrill
# Fletcher Mcconnell
# Fletcher Mcconnell
# Tandra Meadows
# Tandra Meadows
# Devorah Smartt
# Devorah Smartt
# ...

# %% [raw]
# # Find students who scored below pass mark and assigned them as fail, and above pass mark as pass in all the categories.

# %%
x = Collection.aggregate(
[{
    '$project':
    {
        'name':1,
        '_id':0,
        'result':{
            '$cond':
                    {'if':{'$and':[{'$gte':['$Exam',40]},{'gte':['$Quiz',40]},{'$gte':['$Homework',40]}]},
                     'then':'pass',
                     'else':'fail'
                    }
        }
    }
}])

for i in x:
    print(i)
# Out:
# {'name': 'aimee Zank', 'result': 'fail'}
# {'name': 'Aurelia Menendez', 'result': 'pass'}
# {'name': 'Corliss Zuk', 'result': 'pass'}
# {'name': 'Bao Ziglar', 'result': 'pass'}
# {'name': 'Zachary Langlais', 'result': 'fail'}
# {'name': 'Wilburn Spiess', 'result': 'pass'}
# {'name': 'Jenette Flanders', 'result': 'fail'}
# {'name': 'Salena Olmos', 'result': 'pass'}
# {'name': 'Daphne Zheng', 'result': 'fail'}
# {'name': 'Sanda Ryba', 'result': 'fail'}
# {'name': 'Denisha Cast', 'result': 'pass'}
# {'name': 'Marcus Blohm', 'result': 'pass'}
# {'name': 'Quincy Danaher', 'result': 'pass'}
# {'name': 'Jessika Dagenais', 'result': 'pass'}
# {'name': 'Alix Sherrill', 'result': 'fail'}
# {'name': 'Tambra Mercure', 'result': 'pass'}
# {'name': 'Dodie Staller', 'result': 'fail'}
# {'name': 'Fletcher Mcconnell', 'result': 'fail'}
# {'name': 'Verdell Sowinski', 'result': 'pass'}
# {'name': 'Gisela Levin', 'result': 'pass'}
# {'name': 'Tressa Schwing', 'result': 'pass'}
# ...

# %% [raw]
# # Find the total and average of the exam, quiz and homework and store them in a separate collection.

# %%
tot_avg = []

for i in Collection.find({},{'_id':0, 'name':1,'Total':1,'Percentage':1}):
    tot_avg.append(i)

print(tot_avg)
# Out:
# [{'name': 'aimee Zank'}, {'name': 'Aurelia Menendez'}, {'name': 'Corliss Zuk'}, {'name': 'Bao Ziglar'}, {'name': 'Zachary Langlais'}, {'name': 'Wilburn Spiess'}, {'name': 'Jenette Flanders'}, {'name': 'Salena Olmos'}, {'name': 'Daphne Zheng'}, {'name': 'Sanda Ryba'}, {'name': 'Denisha Cast'}, {'name': 'Marcus Blohm'}, {'name': 'Quincy Danaher'}, {'name': 'Jessika Dagenais'}, {'name': 'Alix Sherrill'}, {'name': 'Tambra Mercure'}, {'name': 'Dodie Staller'}, {'name': 'Fletcher Mcconnell'}, {'name': 'Verdell Sowinski'}, {'name': 'Gisela Levin'}, {'name': 'Tressa Schwing'}, {'name': 'Rosana Vales'}, {'name': 'Margart Vitello'}, {'name': 'Tamika Schildgen'}, {'name': 'Jesusa Rickenbacker'}, {'name': 'Rudolph Domingo'}, {'name': 'Jonie Raby'}, {'name': 'Edgar Sarkis'}, {'name': 'Laureen Salomone'}, {'name': 'Gwyneth Garling'}, {'name': 'Kaila Deibler'}, {'name': 'Tandra Meadows'}, {'name': 'Gwen Honig'}, {'name': 'Sadie Jernigan'}, {'name': 'Carli Belvins'}, {'name': 'Synthia Labelle'}, {'n
# ...

# %%
Collection1 = db['Total_percentage']

# %%
for i in range(len(tot_avg)):
    Collection1.insert_one(tot_avg[i])

# %% [raw]
# # Create a new collection which consists of students who scored below average and above 40% in all the categories

# %%
Collection2 = db['avg_student']

# %%
x = Collection.aggregate(
[{
    '$match':
       
         {'$and':[{'Exam':{'$gte':40, '$lte':70}},{'Quiz':{'$gte':40, '$lte':70}},{'Homework':{'$gte':40, '$lte':70}}]
         }
}])

for i in x:
    Collection2.insert_one(i)

# %%
for i in Collection2.find():
    print(i)
# Out:
# {'_id': 65, 'name': 'Gena Riccio', 'Exam': 67.58395308948619, 'Quiz': 67.2413500951588, 'Homework': 42.93471779899529}
# {'_id': 85, 'name': 'Rae Kohout', 'Exam': 63.86894250781692, 'Quiz': 55.81549538273672, 'Homework': 59.13566011309437}
# {'_id': 109, 'name': 'Flora Duell', 'Exam': 40.68238966626067, 'Quiz': 46.77972040308903, 'Homework': 69.29400057020965}
# {'_id': 110, 'name': 'Nobuko Linzey', 'Exam': 67.40792606687442, 'Quiz': 58.58331128403415, 'Homework': 47.44831568815929}
# {'_id': 185, 'name': 'Kam Senters', 'Exam': 49.8822537074033, 'Quiz': 45.29515361387067, 'Homework': 68.88048980292801}
# {'_id': ObjectId('6378bc50d889ccc06dc39aa4'), 'name': 'Gena Riccio', 'Exam': 67.58395308948619, 'Quiz': 67.2413500951588, 'Homework': 42.93471779899529, 'Total': 177.76002098364026, 'Percentage': 59.25334032788009}
# ...

# %% [raw]
# # Create a new collection which consists of students who scored below the fail mark in all the categories

# %%
Collection3 = db['Failed_students']

# %%
x= Collection.aggregate(
[{
    '$match':
         {'$and':[{'Exam':{'$lte':40}},{'Quiz':{'$lte':40}},{'Homework':{'$lte':40}}]
         }
       
}])

for i in x:
    Collection3.insert_one(i)

# %%
for i in Collection3.find():
    print(i)
# Out:
# {'_id': 0, 'name': 'aimee Zank', 'Exam': 1.463179736705023, 'Quiz': 11.78273309957772, 'Homework': 35.8740349954354}
# {'_id': ObjectId('6378bc48d889ccc06dc39a63'), 'name': 'aimee Zank', 'Exam': 1.463179736705023, 'Quiz': 11.78273309957772, 'Homework': 35.8740349954354, 'Total': 49.11994783171814, 'Percentage': 16.373315943906046}

# %% [raw]
# # Create a new collection which consists of students who scored above pass mark in all the categories

# %%
Collection4 = db['Pass_students']

# %%
x= Collection.aggregate(
[{
    '$match':
         {'$and':[{'Exam':{'$gte':40}},{'Quiz':{'$gte':40}},{'Homework':{'$gte':40}}]
         }
       
}])

for i in x:
    Collection4.insert_one(i)

# %%
for i in Collection4.find():
    print(i)
# Out:
# {'_id': 1, 'name': 'Aurelia Menendez', 'Exam': 60.06045071030959, 'Quiz': 52.79790691903873, 'Homework': 71.76133439165544}
# {'_id': 7, 'name': 'Salena Olmos', 'Exam': 90.37826509157176, 'Quiz': 42.48780666956811, 'Homework': 96.52986171633331}
# {'_id': 10, 'name': 'Denisha Cast', 'Exam': 45.61876862259409, 'Quiz': 98.35723209418343, 'Homework': 55.90835657173456}
# {'_id': 11, 'name': 'Marcus Blohm', 'Exam': 78.42617835651868, 'Quiz': 82.58372817930675, 'Homework': 87.49924733328717}
# {'_id': 12, 'name': 'Quincy Danaher', 'Exam': 54.29841278520669, 'Quiz': 85.61270164694737, 'Homework': 80.40732356118075}
# {'_id': 13, 'name': 'Jessika Dagenais', 'Exam': 90.47179954427436, 'Quiz': 90.3001402468489, 'Homework': 95.17753772405909}
# {'_id': 18, 'name': 'Verdell Sowinski', 'Exam': 62.12870233109035, 'Quiz': 84.74586220889356, 'Homework': 81.58947824932574}
# {'_id': 20, 'name': 'Tressa Schwing', 'Exam': 42.17439799514388, 'Quiz': 71.99314840599558, 'Homework': 81.23972632069464}
# ...
